# %%
#Ex 3 - Numbers and Math


print ("I will now count my chickens:")

print("Hens", 25 + 30 / 6)
print("Roosters", 100 - 25 * 3 % 4)

print("Now I will count the eggs:")

print(3 + 2 +1 -5 + 4 % 2 - 1 / 4 + 6)

print("It is true that 3 + 2 < 5 - 7?")

print(3 + 2 < 5 - 7)

print("What is 3 + 2?", 3+2)
print("What is 5-7?", 5-7)

print("Oh, that's why it's False.")

print("How about some more.")

print("is it greater?", 5 > -2)
print("Is it greater or equal?", 5 <= -2)
print("Is it less or equal?", 5<= -2)

# Post Code Notes:

# Numbers in string do not require quotes - as in line 5 a calculation will still be returned
# If a number and arithmetic are applied inside a string, its recognized as just a string - will not return a calculation
# Any operations that involve a comparison will return a Boolean value (True or False)
# the only way to get math to print along with a string, is to add a comma and add it outside of string
# Out:
# I will now count my chickens:
# Hens 30.0
# Roosters 97
# Now I will count the eggs:
# 6.75
# It is true that 3 + 2 < 5 - 7?
# False
# What is 3 + 2? 5
# What is 5-7? -2
# Oh, that's why it's False.
# How about some more.
# is it greater? True
# Is it greater or equal? False
# Is it less or equal? False

# %%
1+2
# Out:
# 3

# %%
# Study Drill 3

print(" How many can you eat in 30 seconds?")   #Maybe 60 who knows 

print(" how about 12 + 3?" , 12+3)
# Out:
#  How many can you eat in 30 seconds?
#  how about 12 + 3? 15
