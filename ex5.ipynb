# %%
#Ex 5 - More Variables and Printing


name = 'Wonder Woman'
age = 23       #Truth or Truth?
height = 65 * round(2.54)   #inches converted to centimeters
weight = 189 / round(2.205) #lbs converted to kilos
eyes = 'Green'   
teeth = 'Dark Yellow'
hair = 'Dirty Blonde'


print(f"Let's talk about {name}.")
print(f"She's {height} centimeters tall.")
print(f"She's {weight} kilograms light.")
print(f"Actually that's not too heavy.")
print(f"She's got {eyes} eyes and {hair} hair.")
print(f"Her teeth are usually {teeth} depending on the coffee.")

total = age + height + weight
print(f"If I add {age}, {height}, and {weight} I get {total}.")
# Out:
# Let's talk about Wonder Woman.
# She's 195 centimeters tall.
# She's 94.5 kilograms light.
# Actually that's not too heavy.
# She's got Green eyes and Dirty Blonde hair.
# Her teeth are usually Dark Yellow depending on the coffee.
# If I add 23, 195, and 94.5 I get 312.5.
