# %%
#Ex  10 - Escape Codes in Strings

#The Most Commonly Used Escape Characters
#\n   # new line
#\t   # tab
#\\   # backslash
#\"   # double quote
#\'   # single quote
#Test Other Escape Chars

tabby_cat = "\N{DRAGON}I'm tabbed in."
persian_cat = "I'm split\non a line."
backslash_cat = "I'm \\ a \\ cat."

fat_cat = '''
I'll do a list:
\t* Cat Food 
\t* Fishies
\t* Catnip\n\t* Grass
'''

print(tabby_cat)
print(persian_cat)
print(backslash_cat)
print(fat_cat)
# Out:
# 🐉I'm tabbed in.
# I'm split
# on a line.
# I'm \ a \ cat.
#
# I'll do a list:
# 	* Cat Food
# 	* Fishies
# 	* Catnip
# 	* Grass
