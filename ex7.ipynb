# %%
#Jessica Suarez
# Ex 8


print(" Mary had a little lamb.")   
print("Its fleece was white as {}.".format('snow'))    #format string {} is a placeholder, and its replaced with snow
print("And everywhere that Mary went.")
print("." * 10)  #what'd that do?   #printed 10 . in a row to use as a divider

end1 = "C"    # end prints a single character on each line
end2 = "h"
end3 = "e"
end4 = "e"
end5 = "s"
end6 = "e"
end7 = "B"
end8 = "u"
end9 = "r"
end10 = "g"
end11 = "e"      
end12 = "r"

# watch end = ' ' at the end. try removing it to see what happens

print(end1 + end2 + end3 + end4 + end5 + end6, end=' ')  #print adds each line together to form the word cheese
print(end7 + end8 + end9 + end10 + end11 + end12)  #print adds each line together to form the word burger
# Out:
#  Mary had a little lamb.
# Its fleece was white as snow.
# And everywhere that Mary went.
# ..........
# Cheese Burger
