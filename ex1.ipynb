# %%
#Ex 1 - A Good First Program

print("Hello World!")
print("Hello Again")
print("I like typing this.")
print("This is fun.")
print('Yay! Printing.')
print("I'd mucch rather you 'not'.")
print('I "said" do not touch this.')
# Out:
# Hello World!
# Hello Again
# I like typing this.
# This is fun.
# Yay! Printing.
# I'd mucch rather you 'not'.
# I "said" do not touch this.
